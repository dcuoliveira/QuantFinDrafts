# %%
import numpy as np
import pandas as pd
import os
import pickle
import statsmodels.api as sm
from IPython.display import display

current_dir = os.getcwd()

# %%
data = pd.read_excel(os.path.join(current_dir, 'data', "signals_bars_vols.xlsx"), sheet_name="bars")
data.set_index('date', inplace=True)

# %%
data.tail()
# Out:
#             USDBRL   USDZAR  USDCLP   USDCOP   USDMXN  USDHUF  USDPLN  \
# date
# 2021-10-25  5.5568  14.7142  808.47  3772.66  20.1718  315.00  3.9742
# 2021-10-26  5.5668  14.8495  805.67  3774.91  20.2139  314.82  3.9748
# 2021-10-27  5.5384  15.0832  806.18  3758.40  20.3110  313.14  3.9832
# 2021-10-28  5.6465  15.1345  806.65  3771.98  20.3710  309.43  3.9597
# 2021-10-29  5.6365  15.2412  813.85  3780.24  20.5633  311.57  3.9889
#
#              USDCZK   USDKRW  USDJPY  USDAUD  USDCAD  USDNZD  USDGBP  USDNOK  \
# date
# 2021-10-25  22.1659  1168.26  113.71  1.3348  1.2382  1.3957  0.7265  8.3538
# 2021-10-26  22.1712  1167.05  114.16  1.3332  1.2390  1.3962  0.7264  8.3656
# 2021-10-27  22.1643  1170.43  113.83  1.3301  1.2359  1.3949  0.7279  8.4207
# 2021-10-28  22.0340  1169.58  113.58  1.3256  1.2346  1.3887  0.7249  8.3316
# 2021-10-29  22.1975  1168.40  113.95  1.3301  1.2388  1.3948  0.7305  8.4437
#
#             USDSEK  EURUSD   USDCHF
# date
# ...

# %% [markdown]
# ## LATAM countries

# %%
LATAM = ["USDBRL", "USDCLP", "USDCOP", "USDMXN", "USDZAR"]
latam_df = data[LATAM]
# Out:
#             USDBRL  USDCLP  USDCOP  USDMXN  USDZAR
# date
# 2000-01-03  1.8190  9.5050  250.56  4.1250  6.1315
# 2000-01-04  1.8510  9.5713  246.88  4.1225  6.0900
# 2000-01-05  1.8390  9.5710  246.60  4.1245  6.0684
# 2000-01-06  1.8415  9.5800  246.57  4.0810  6.0788
# 2000-01-07  1.8270  9.5650  247.35  4.0750  6.0575

# %%
latam_df.plot()
# Out:
# <AxesSubplot:xlabel='date'>
